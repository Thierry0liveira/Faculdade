# %% [markdown]
# <a href="https://colab.research.google.com/github/Thierry0liveira/Faculdade/blob/main/Classifica%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# APRENDIZAGEM SUPERVISIONADA: CLASSIFICAÇÃO

# %% [markdown]
#   Este projeto tem por objetivo desenvolver um algoritmo de Machine Learning para prever tendência de uma pessoa desenvolver algum tipo de doença cardíaca com base em fatores clínicos e laboratoriais

# %% [markdown]
# **PRÉ-PROCESSAMENTO**

# %%
# Importar as bibliotecas
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/heart_tratado.csv', sep=';', encoding='utf-8')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140        289.0          0     Normal    172
# 1   49   F           NAP        160        180.0          0     Normal    156
# 2   37   M           ATA        130        283.0          0         ST     98
# 3   48   F           ASY        138        214.0          0     Normal    108
# 4   54   M           NAP        150        195.0          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (917, 12)

# %%
# Variáveis de tipos diferentes
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol       float64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %% [markdown]
# Transformando as variáveis categóricas nominais em variáveis categóricas ordinais

# %%
df2 = pd.DataFrame.copy(df)

# %% [markdown]
# Transformar

# %%
df2['Sex'].replace({'M': 0, 'F': 1}, inplace=True)
df2['ChestPainType'].replace({'ATA': 0, 'NAP': 1, 'ASY': 2, 'TA': 3}, inplace=True)
df2['RestingECG'].replace({'Normal': 0, 'ST': 1, 'LVH': 2}, inplace=True)
df2['ExerciseAngina'].replace({'N': 0, 'Y': 1}, inplace=True)
df2['ST_Slope'].replace({'Up': 0, 'Flat': 1, 'Down': 2}, inplace=True)
# Out:
# /tmp/ipython-input-2976004778.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Sex'].replace({'M': 0, 'F': 1}, inplace=True)
# /tmp/ipython-input-2976004778.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2['Sex'].replace({'M': 0, 'F': 1}, inplace=True)
# ...

# %%
df2.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              0        140        289.0          0           0
# 1   49    1              1        160        180.0          0           0
# 2   37    0              0        130        283.0          0           1
# 3   48    1              2        138        214.0          0           0
# 4   54    0              1        150        195.0          0           0
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         0             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         0             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         0             0

# %%
# transformamos tudo em números
df2.dtypes
# Out:
# Age                 int64
# Sex                 int64
# ChestPainType       int64
# RestingBP           int64
# Cholesterol       float64
# FastingBS           int64
# RestingECG          int64
# MaxHR               int64
# ExerciseAngina      int64
# Oldpeak           float64
# ST_Slope            int64
# HeartDisease        int64
# dtype: object

# %% [markdown]
# # **LEGENDA**

# %% [markdown]
# Age = idade (anos)
#
# Sex = sexo (0=M; 1=F)
#
# Chest Pain Type = tipo de dor no peito (0=TA:angina típica; 1=ATA:angina atípica; 2=NAP:dor não anginosa; 3=ASY:assintomático)
#
# Resting BP = pressão sanguínea em repouso (mmHg)
#
# Cholesterol = colesterol sérico (mg/dl)
#
# Fasting BS = açúcar no sangue em jejum (mg/dl) 0: Fasting BS < 120 mg/dl (não diabético) 1: Fasting BS >= 120 mg/dl, (diabético)
#
# Resting ECG = eletrocardiograma em repouso (0=Normal; 1=ST:Anormalidade da onda ST-T; 2=LVH: Hipertrofia ventricular esquerda)
#
# Max HR = frequência cardíaca máxima
#
# Exercise Angina = Angina induzida por exercício (0=Não; 1=Sim)
#
# Old Peak = Depressão de ST induzida por exercício em relação ao repouso
#
# ST_Slope = Inclinação do segmento ST (0=UP; 1=Flat; 2=Down)
#
# Heart Disease = Doença cardíaca (0=Não possui doença cardíaca; 1=Possui doença cardíaca)

# %% [markdown]
# **# Previsores**

# %%
previsores = df2.iloc[:, 0:11].values

# %%
previsores
# Out:
# array([[40. ,  0. ,  0. , ...,  0. ,  0. ,  0. ],
#        [49. ,  1. ,  1. , ...,  0. ,  1. ,  1. ],
#        [37. ,  0. ,  0. , ...,  0. ,  0. ,  0. ],
#        ...,
#        [57. ,  0. ,  2. , ...,  1. ,  1.2,  1. ],
#        [57. ,  1. ,  0. , ...,  0. ,  0. ,  1. ],
#        [38. ,  0. ,  1. , ...,  0. ,  0. ,  0. ]])

# %%
# tirou uma coluna que foi a coluna dos indexadores
previsores.shape
# Out:
# (917, 11)

# %%
alvo = df2.iloc[:, 11].values

# %%
alvo.shape
# Out:
# (917,)

# %%
df2.describe()
# Out:
#               Age         Sex  ChestPainType   RestingBP  Cholesterol  \
# count  917.000000  917.000000     917.000000  917.000000   917.000000
# mean    53.509269    0.210469       1.452563  132.540894   244.635389
# std      9.437636    0.407864       0.852166   17.999749    53.347125
# min     28.000000    0.000000       0.000000   80.000000    85.000000
# 25%     47.000000    0.000000       1.000000  120.000000   214.000000
# 50%     54.000000    0.000000       2.000000  130.000000   244.635389
# 75%     60.000000    0.000000       2.000000  140.000000   267.000000
# max     77.000000    1.000000       3.000000  200.000000   603.000000
#
#         FastingBS  RestingECG       MaxHR  ExerciseAngina     Oldpeak  \
# count  917.000000  917.000000  917.000000      917.000000  917.000000
# mean     0.233370    0.604144  136.789531        0.404580    0.886696
# std      0.423206    0.806161   25.467129        0.491078    1.066960
# ...

# %% [markdown]
# Padronização (utiliza a média e o desvio padrão como referência)
#
# Normalização (utiliza os valores máximo e mínimo como referência)

# %%
from sklearn.preprocessing import StandardScaler

# %%
previsores_esc = StandardScaler().fit_transform(previsores)

# %%
previsores_esc
# Out:
# array([[-1.43220634, -0.51630861, -1.70548479, ..., -0.82431012,
#         -0.83150225, -1.05109458],
#        [-0.47805725,  1.9368261 , -0.5313635 , ..., -0.82431012,
#          0.10625149,  0.59651863],
#        [-1.75025603, -0.51630861, -1.70548479, ..., -0.82431012,
#         -0.83150225, -1.05109458],
#        ...,
#        [ 0.37007527, -0.51630861,  0.64275778, ...,  1.21313565,
#          0.29380223,  0.59651863],
#        [ 0.37007527,  1.9368261 , -1.70548479, ..., -0.82431012,
#         -0.83150225,  0.59651863],
#        [-1.64423947, -0.51630861, -0.5313635 , ..., -0.82431012,
#         -0.83150225, -1.05109458]])

# %%
previsoresdf = pd.DataFrame(previsores_esc)

# %%
previsoresdf
# Out:
#            0         1         2         3         4         5         6   \
# 0   -1.432206 -0.516309 -1.705485  0.414627  0.832075 -0.551733 -0.749818
# 1   -0.478057  1.936826 -0.531364  1.526360 -1.212261 -0.551733 -0.749818
# 2   -1.750256 -0.516309 -1.705485 -0.141240  0.719543 -0.551733  0.491306
# 3   -0.584074  1.936826  0.642758  0.303453 -0.574578 -0.551733 -0.749818
# 4    0.052026 -0.516309 -0.531364  0.970493 -0.930931 -0.551733 -0.749818
# ..        ...       ...       ...       ...       ...       ...       ...
# 912 -0.902124 -0.516309  1.816879 -1.252973  0.363191 -0.551733 -0.749818
# 913  1.536257 -0.516309  0.642758  0.636973 -0.968441  1.812470 -0.749818
# 914  0.370075 -0.516309  0.642758 -0.141240 -2.131275 -0.551733 -0.749818
# 915  0.370075  1.936826 -1.705485 -0.141240 -0.161960 -0.551733  1.732430
# 916 -1.644239 -0.516309 -0.531364  0.303453 -1.306038 -0.551733 -0.749818
#
#            7         8         9         10
# ...

# %%
previsoresdf.describe()
# Out:
#                  0             1             2             3             4   \
# count  9.170000e+02  9.170000e+02  9.170000e+02  9.170000e+02  9.170000e+02
# mean   1.859654e-16  7.748558e-18  1.084798e-16  7.767929e-16 -1.869340e-16
# std    1.000546e+00  1.000546e+00  1.000546e+00  1.000546e+00  1.000546e+00
# min   -2.704405e+00 -5.163086e-01 -1.705485e+00 -2.920572e+00 -2.994023e+00
# 25%   -6.900904e-01 -5.163086e-01 -5.313635e-01 -6.971063e-01 -5.745784e-01
# 50%    5.202558e-02 -5.163086e-01  6.427578e-01 -1.412398e-01  0.000000e+00
# 75%    6.881250e-01 -5.163086e-01  6.427578e-01  4.146267e-01  4.194568e-01
# max    2.490407e+00  1.936826e+00  1.816879e+00  3.749826e+00  6.721265e+00
#
#                  5           6             7             8             9   \
# count  9.170000e+02  917.000000  9.170000e+02  9.170000e+02  9.170000e+02
# mean   4.649135e-17    0.000000 -5.114048e-16 -1.046055e-16  7.748558e-17
# ...
